# %% [markdown]
# <a href="https://colab.research.google.com/github/JSJeong-me/RPA-2023/blob/main/pdf/camelot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install camelot-py

# %%
# !pip show camelot-py

# %%
# !apt install ghostscript python3-tk

# %%
# !pip install ghostscript==0.7

# %%
import camelot

# %%
tables = camelot.read_pdf('ICSC.pdf', flavor="lattice", pages= "all" )

# %%
len(tables)
# Out:
# 8

# %%
tables[7]
# Out:
# <Table shape=(2, 1)>

# %%
tables[7].df
# Out:
#                                                    0
# 0                                              NOTES
# 1  Immediate administration of an appropriate inh...

# %%
# tables = camelot.read_pdf('foo.pdf', f='excel', flavor='stream') #, compress=True

# %%
len(tables)
# Out:
# 8

# %%
tables[0].df

# %%
tables[4].parsing_report
# Out:
# {'accuracy': 97.74, 'whitespace': 33.33, 'order': 1, 'page': 2}

# %%
tables[7].to_excel('file3.xlsx')
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py:211: FutureWarning: the 'encoding' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'encoding'
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/camelot/core.py:616: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()

# %%
tables[0].df

# %%
plots = camelot.plot(tables[7], kind='contour')
plots.show() # plot을 화면에 띄우기

# %%
plots = camelot.plot(tables[4], kind='grid')
plots.show() # plot을 화면에 띄우기

# %%
# plots = camelot.plot(tables[0], kind='joint')
# plots.show() # plot을 화면에 띄우기

# %%
plots = camelot.plot(tables[7], kind='text')
plots.show() # plot을 화면에 띄우기
